# %%
import json
import requests
import pandas as pd

URL = "https://transparencia.queimados.rj.gov.br/sincronia/apidados.rule?sys=LAI"

def consultar_despesas_todas(ano: int) -> pd.DataFrame:
    """
    Consulta a API despesas_todas e retorna um DataFrame com os dados.
    """

    payload = {
        "api": "despesas_todas",
        "ano": ano
    }

    headers = {
        "Content-Type": "application/json",
        "Accept": "application/json"
    }

    print(f"🔎 Consultando despesas_todas para {ano}...")

    try:
        response = requests.post(URL, data=json.dumps(payload), headers=headers)
        response.raise_for_status()
        data = response.json()

    except Exception as e:
        print("❌ Erro de conexão ou requisição:", e)
        return pd.DataFrame()

    # -------------------
    # Tratamento de erros retornados pela API
    # -------------------
    status = data.get("status", "").lower()

    if status != "sucess" and status != "success":
        print("⚠️ Retorno de erro da API:", data.get("retorno", data))
        return pd.DataFrame()

    registros = data.get("dados", [])

    if not registros:
        print("⚠️ API retornou lista vazia.")
        return pd.DataFrame()

    # Converter para DataFrame
    df = pd.DataFrame(registros)

    print(f"✅ {len(df)} registros carregados")
    return df


# Exemplo de uso
df_2025 = consultar_despesas_todas(2025)
# Out:
# 🔎 Consultando despesas_todas para 2025...
# ✅ 8804 registros carregados

# %%
df_2025.head()
# Out:
#   EMP_PROCESSO_COMPLETO  CPF_CNPJ_FORMATADA Tipo Valor_Estornado   ano  \
# 0         00002126/2023  34.028.316/0002-94    J            0.00  2025
# 1         00000900/2024  34.028.316/0002-94    J            0.00  2025
# 2         00000900/2024  34.028.316/0002-94    J            0.00  2025
# 3         00006591/2024  26.681.836/0001-92    J        35142.13  2025
# 4         00006591/2024  26.681.836/0001-92    J            0.00  2025
#
#                                               Objeto valor_despesa  \
# 0  COMPLEMENTAÇÃO DA NE 717/2024.CELEBRAÇÃO DO QU...       2354.58
# 1  PAGAMENTO REFERENTE À PRESTAÇÃO DE SERVIÇOS DA...       2354.58
# 2  PAGAMENTO REFERENTE À PRESTAÇÃO DE SERVIÇOS DA...       2354.58
# 3  CONTRATAÇÃO DE EMPRESA JKN ASSESSORIA E SERVIC...      35142.13
# 4  CONTRATAÇÃO DE EMPRESA JKN ASSESSORIA E SERVIC...      35142.13
#
#   valor_despesa_total                                            dotacao  \
# 0             2354.58  25101.04.122.0001.2000 - 3390394701 - Fonte: 7...
# 1             2354.58  25101.04.122.0001.2000 - 3390394701 - Fonte: 7...
# 2             2354.58  25101.04.122.0001.2000 - 3390394701 - Fonte: 7...
# 3                0.00  47101.12.361.0061.1261 - 4490510000 - Fonte: 5...
# 4            35142.13  47101.12.361.0061.1263 - 4490510000 - Fonte: 5...
#
#                               descricao_favorecido  ... elemento_despesa  \
# 0  EMPRESA BRASILEIRA DE CORREIOS E TELEGRAFOS-ETC  ...           339039
# 1  EMPRESA BRASILEIRA DE CORREIOS E TELEGRAFOS-ETC  ...           339039
# 2  EMPRESA BRASILEIRA DE CORREIOS E TELEGRAFOS-ETC  ...           339039
# 3                   JKN ASSESSORIA E SERVICOS LTDA  ...           449051
# 4                   JKN ASSESSORIA E SERVICOS LTDA  ...           449051
#
#                        descricao_elemento_despesa  \
# 0  Outros Serviços de Terceiros - Pessoa Jurídica
# 1  Outros Serviços de Terceiros - Pessoa Jurídica
# 2  Outros Serviços de Terceiros - Pessoa Jurídica
# 3                             Obras e Instalações
# 4                             Obras e Instalações
#
#                                                 acao  \
# 0  2000 - MANUTENÇÃO E OPERACIONALIZAÇÃO ADMINIST...
# 1  2000 - MANUTENÇÃO E OPERACIONALIZAÇÃO ADMINIST...
# 2  2000 - MANUTENÇÃO E OPERACIONALIZAÇÃO ADMINIST...
# 3  1261 - CONSTRUÇÃO, REFORMA, AMPLIAÇÃO E/OU REA...
# 4  1263 - CONSTRUÇÃO DA ESCOLA MUNICIPAL ANNA MAR...
#
#                                             PROGRAMA valor_liquidado  \
# 0  0001 - GESTÃO ADMINISTRATIVA EFICIENTE E EFICA...         2354.58
# 1  0001 - GESTÃO ADMINISTRATIVA EFICIENTE E EFICA...            0.00
# 2  0001 - GESTÃO ADMINISTRATIVA EFICIENTE E EFICA...         2354.58
# 3       0061 - UNIVERSALIZAÇÃO DO ENSINO FUNDAMENTAL        35142.13
# 4       0061 - UNIVERSALIZAÇÃO DO ENSINO FUNDAMENTAL        35142.13
#
#   valor_estorno_liquidacao valor_retido valor_estorno_pagamento  \
# 0                     0.00         0.00                    0.00
# 1                     0.00         0.00                    0.00
# 2                     0.00         0.00                    0.00
# 3                     0.00         0.00                    0.00
# 4                     0.00         0.00                    0.00
#
#   valor_pago_liquido Estorno_do_Empenho
# 0            2354.58                NÃO
# 1            2354.58
# 2               0.00
# 3               0.00
# 4               0.00
#
# [5 rows x 38 columns]

# %%
df_2025.columns
# Out:
# Index(['EMP_PROCESSO_COMPLETO', 'CPF_CNPJ_FORMATADA', 'Tipo',
#        'Valor_Estornado', 'ano', 'Objeto', 'valor_despesa',
#        'valor_despesa_total', 'dotacao', 'descricao_favorecido',
#        'unidade_orcamentaria', 'natureza_despeza', 'fonte', 'funcao',
#        'subfuncao', 'orgao', 'modalidade_licitacao', 'data_despesa',
#        'nome_secretria', 'empenho', 'OP', 'codigo_interno', 'Despesa',
#        'numero_licitacao', 'catagoria_economica', 'catagoria_descricao',
#        'grupo_despesa', 'grupo_descricao', 'elemento_despesa',
#        'descricao_elemento_despesa', 'acao', 'PROGRAMA', 'valor_liquidado',
#        'valor_estorno_liquidacao', 'valor_retido', 'valor_estorno_pagamento',
#        'valor_pago_liquido', 'Estorno_do_Empenho'],
#       dtype='object')

# %%
df_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8804 entries, 0 to 8803
# Data columns (total 38 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   EMP_PROCESSO_COMPLETO       8804 non-null   object
#  1   CPF_CNPJ_FORMATADA          8804 non-null   object
#  2   Tipo                        8804 non-null   object
#  3   Valor_Estornado             8804 non-null   object
#  4   ano                         8804 non-null   int64
#  5   Objeto                      8801 non-null   object
#  6   valor_despesa               8804 non-null   object
#  7   valor_despesa_total         8804 non-null   object
#  8   dotacao                     8804 non-null   object
#  9   descricao_favorecido        8804 non-null   object
#  10  unidade_orcamentaria        8804 non-null   object
#  11  natureza_despeza            8804 non-null   object
#  12  fonte                       8804 non-null   object
#  13  funcao                      8804 non-null   object
#  14  subfuncao                   8804 non-null   object
#  15  orgao                       8804 non-null   object
#  16  modalidade_licitacao        8804 non-null   object
#  17  data_despesa                8804 non-null   object
#  18  nome_secretria              8804 non-null   object
#  19  empenho                     8804 non-null   object
#  20  OP                          8795 non-null   object
#  21  codigo_interno              8804 non-null   int64
#  22  Despesa                     8804 non-null   object
#  23  numero_licitacao            8804 non-null   object
#  24  catagoria_economica         8804 non-null   object
#  25  catagoria_descricao         8804 non-null   object
#  26  grupo_despesa               8804 non-null   object
#  27  grupo_descricao             8804 non-null   object
#  28  elemento_despesa            8804 non-null   object
#  29  descricao_elemento_despesa  8792 non-null   object
#  30  acao                        8804 non-null   object
#  31  PROGRAMA                    8804 non-null   object
#  32  valor_liquidado             8804 non-null   object
#  33  valor_estorno_liquidacao    8804 non-null   object
#  34  valor_retido                8804 non-null   object
#  35  valor_estorno_pagamento     8804 non-null   object
#  36  valor_pago_liquido          8804 non-null   object
#  37  Estorno_do_Empenho          8804 non-null   object
# dtypes: int64(2), object(36)
# memory usage: 2.6+ MB

# %%
df_2025['valor_pago_liquido'].iloc[0:10]
# Out:
# 0     2354.58
# 1     2354.58
# 2        0.00
# 3        0.00
# 4        0.00
# 5    32949.25
# 6    32949.25
# 7    32949.25
# 8    32949.25
# 9        0.00
# Name: valor_pago_liquido, dtype: object

# %%
# fazendo o tratamento de valor_pago_liquido para float
df_2025['valor_pago_liquido'] = df_2025['valor_pago_liquido'].str.replace(',', '.').astype(float)
df_2025['valor_pago_liquido'].iloc[0:10]
# Out:
# 0     2354.58
# 1     2354.58
# 2        0.00
# 3        0.00
# 4        0.00
# 5    32949.25
# 6    32949.25
# 7    32949.25
# 8    32949.25
# 9        0.00
# Name: valor_pago_liquido, dtype: float64

# %%
df_2025['valor_pago_liquido'].sum()
# Out:
# np.float64(822416654.69)
